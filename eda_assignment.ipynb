# %% [markdown]
# EDA - 1
#
# 1. What is the range of selling prices in the dataset?
#
# The range of selling prices is from ₹5,000 to ₹7,60,000. This indicates a wide variety of bikes, including both affordable and premium models.
#
#
#
# 2. What is the median selling price for bikes in the dataset?
#
# The median selling price is ₹45,000. This represents the middle value of the selling prices, suggesting that half the bikes are sold for less than ₹45,000 and half for more.
#
#
#
# 3. What is the most common seller type?
# The most common seller type is Individual. This shows that the majority of bikes in the dataset are listed by private sellers rather than dealers.
#
#
#
# 4. How many bikes have driven more than 50,000 kilometers?
#
# A total of 170 bikes in the dataset have driven more than 50,000 kilometers, indicating a significant number of heavily used bikes.
#
#
#
#
# 5. What is the average km_driven value for each ownership type?
#
# 1st owner: 32,816.6 km (on average, less driven and likely newer bikes).
# 2nd owner: 39,289.0 km (moderately used bikes).
# 3rd owner: 33,292.2 km (similar usage as 1st owners, indicating potential re-selling).
# 4th owner: 311,500.0 km (outliers or exceptionally high usage, possibly very old bikes).
#
#
#
#
#
# 6. What proportion of bikes are from the year 2015 or older?
#
# Approximately 56.6% of the bikes in the dataset are from 2015 or earlier, highlighting that over half the bikes are relatively older models.
#
#
# 7. What is the trend of missing values across the dataset?
#
# The column ex_showroom_price contains missing values, with 435 entries missing out of 1,061. All other columns are complete.
#
#
#
#
# 8. What is the highest ex_showroom_price recorded, and for which bike?
#
# Harley-Davidson Street Bob - 1278000
#
#
#
# 9. What is the total number of bikes listed by each seller type?
#
# Individual type = 1055
# Dealer Type = 6
#
# 10. What is the relationship between selling_price and km_driven for first-owner bikes?
#
# The scatter plot indicates that higher km_driven values generally correspond to lower selling_price, though there are some exceptions.
# A negative correlation likely exists, where higher usage (km driven) reduces the resale value.
#
#
# 11. Identify and remove outliers in the km_driven column using the IQR method
#
# IQR Calculation:
# Q1 (25th Percentile): Lower bound = -31,500.
# Q3 (75th Percentile): Upper bound = 84,500.
# These values define the acceptable range for km_driven.
#
# Results:
# Rows before outlier removal: 924.
# Rows after outlier removal: 889.
# Total outliers removed: 35 rows.
# Outliers outside the range of -31,500 to 84,500 km have been excluded.
#
# 12.  Perform a bivariate analysis to visualize the relationship between year and selling_price
#
# The scatter plot above shows the relationship between year and selling_price:
# Newer bikes (recent manufacturing years) generally have higher selling prices.
# Older bikes tend to depreciate in value, though some exceptions (likely premium or well-maintained models) retain higher prices.
#
# 13. What is the average depreciation in selling price based on the bike's age (current year - manufacturing year)
#
# The average annual depreciation in selling price is approximately ₹5,886.
#
# 14. Which bike names are priced significantly above the average price for their manufacturing year
#
# A total of 157 bikes are priced significantly (1.5x above) the average price for their manufacturing year.
# Example:
# Yamaha YZF R3
# Royal Enfield Continental GT 650
# Yamaha RX135
#
# 15. Develop a correlation matrix for numeric columns and visualize it using a heatmap
#
# The heatmap above illustrates the relationships between numeric variables:
#
# Selling Price and Year: A strong positive correlation, indicating that newer bikes generally have higher selling prices.
# Selling Price and KM Driven: A weak negative correlation, suggesting that higher mileage slightly reduces the selling price.
# Age and Selling Price: A strong negative correlation, showing that older bikes tend to have lower resale values.

# %% [markdown]
# EDA -2
#
# 1. What is the average selling price of cars for each dealer, and how does it compare across different dealers?
#
# Average selling price of cars for each dealer: Dealers have average prices ranging from $27,217 to $28,189;
# U-Haul CO: $28,770 (highest).
# Classic Chevy: $28,602.
# Buddy Storbeck's Diesel Service Inc: $27,217 (lowest among the listed).
# The difference is relatively small
#
#
#
# 2. Which car brand (Company) has the highest variation in prices, and what does this tell us about the pricing trends?
#
# Car brand with the highest price variation: Lincoln has the highest price variation, with a standard deviation of $19,658, indicating diverse pricing.
#
# 3. What is the distribution of car prices for each transmission type, and how do the interquartile ranges compare?
#
# The distribution of car prices by transmission type is as follows:
#
# Auto:
# Median: $24,000.
# Interquartile Range (IQR): $16,500.
#
# Manual:
# Median: $22,001.
# IQR: $17,000.
# Manual transmissions have a slightly larger IQR, indicating a wider spread in car prices.
#
#
#
# 4. What is the distribution of car prices across different regions?
#
# The distribution of car prices across regions shows:
#
# Aurora: Median $23,000; IQR $17,000; max $85,800.
#
# Austin: Median $23,801; IQR $17,000; max $85,601.
#
# Greenville: Median $22,500; IQR $16,500; max $85,200.
#
# Janesville: Median $23,000; IQR $16,000; max $85,400.
#
# Scottsdale: Median $22,600; IQR $15,500; max $85,001.
#
# The regions show similar price distributions, with minor variations in medians and interquartile ranges.
#
#
# 5. What is the distribution of cars based on body styles?
#
# The distribution of cars by body styles is:
#
# SUV: 6,374 cars
#
# Hatchback: 6,128 cars.
#
# Sedan: 4,488 cars.
#
# Passenger: 3,945 cars.
#
# Hardtop: 2,971 cars.
#
# SUVs and Hatchbacks are the most popular body styles.
#
#
#
#
# 6. How does the average selling price of cars vary by customer gender and annual income?
#
# The average selling price of cars varies by gender and income bracket:
#
# Females:
# Income ≤ $2.25M: $28,219.
# Income $2.25M–$4.49M: $30,183.
# Sparse data for higher income brackets.
#
# Males:
# Income ≤ $2.25M: $27,996.
# Income $2.25M–$4.49M: $29,022.
# Income $6.72M–$8.96M: $40,333.
#
# Males in higher income brackets tend to spend more, but data for very high incomes is limited.
#
# 7. What is the distribution of car prices by region, and how does the number of cars sold vary by region?
#
# Distribution of Car Prices by Region:
#
# Aurora: Median $23,000, IQR $17,000, max $85,800.
# Austin: Median $23,801, IQR $17,000, max $85,601.
# Greenville: Median $22,500, IQR $16,500, max $85,200.
# Janesville: Median $23,000, IQR $16,000, max $85,400.
# Pasco: Median $23,000, IQR $15,500, max $85,600.
# Scottsdale: Median $22,600, IQR $15,500, max $85,001.
#
# Number of Cars Sold by Region:
# Austin: 4,135 cars (highest).
# Greenville and Middletown: 3,128 cars each (lowest).
# Car prices are consistent across regions, with Austin leading in the number of sales.
#
# 8. How does the average car price differ between cars with different engine sizes?
#
# i was not able to find
#
# 9. How do car prices vary based on the customer's annual income bracket?
#
# Variation in Car Prices by Annual Income Bracket:
#
# Income ≤ $2.25M: Median $23,000, IQR $16,000, max $85,800.
#
# Income $2.25M–$4.49M: Median $24,000, IQR $18,750, max $85,001.
#
# Income $4.49M–$6.72M: Median $23,500, IQR $14,500, max $85,601.
#
# Income $6.72M–$8.96M: Median $21,000, IQR $35,000, max $85,000.
#
# Income $8.96M–$11.2M: Median $26,001 (single data point).
#
# The majority of sales are concentrated in lower income brackets, while higher brackets show sparse data but higher variability
#
#
#
# 10. What are the top 5 car models with the highest number of sales, and how does their price distribution look?
#
# Top 5 Car Models with the Highest Sales and Their Price Distribution:
#
# Diamante (418 sales):
#
# Median: $19,001
# IQR: $4,000
# Max: $49,801
# Silhouette (411 sales):
#
# Median: $25,000
# IQR: $20,499
# Max: $60,750
# Prizm (411 sales):
#
# Median: $22,000
# IQR: $9,000
# Max: $44,700
# Passat (391 sales):
#
# Median: $20,000
# IQR: $15,000
# Max: $32,501
# Ram Pickup (383 sales):
#
# Median: $21,000
# IQR: $20,300
# Max: $57,750
# The Silhouette has the widest price range, while the Diamante has the narrowest.
#
# 11. How does car price vary with engine size across different car colors, and which colors have the highest price variation?
#
# the car colors with the highest price variation are:
# Red: $15,519 (highest variation).
# Black: $15,286.
# Pale White: $14,077.
#
# 12. is there any seasonal trend in car sales based on the date of sale?
#
# Seasonal Trends in Car Sales:
# Sales gradually increase throughout the year, peaking in November (3,470) and December (3,546).
# The lowest sales occur in January (790) and February (735).
# This suggests a strong year-end trend in car sales, likely influenced by promotions or holiday seasons.
#
# 13. How does the car price distribution change when considering different combinations of body style and transmission type?
#
# Car Price Distribution by Body Style and Transmission Type:
#
# Hardtop:
# Auto: Median $27,000; IQR $22,124; max $75,501.
# Manual: Median $22,001; IQR $11,425; max $82,500.
#
# Hatchback:
# Auto: Median $21,500; IQR $13,999; max $75,700.
# Manual: Median $23,000; IQR $19,001; max $85,600.
#
# Passenger:
# Auto: Median $25,000; IQR $19,000; max $69,801.
# Manual: Median $22,000; IQR $21,999; max $85,800.
#
# SUV:
# Auto: Median $25,000; IQR $14,000; max $75,501.
# Manual: Median $22,000; IQR $11,000; max $85,500.
#
# Sedan:
# Auto: Median $26,000; IQR $20,500; max $69,980.
# Manual: Median $25,000; IQR $17,599; max $69,700.
#
# Manual transmissions generally show greater variability in prices across body styles.
#
# 14. What is the correlation between car price, engine size, and annual income of customers, and how do these features interact?
#
# Car price and annual income: Very weak positive correlation (0.012), indicating minimal interaction between these variables.
#
# 15. How does the average car price vary across different car models and engine types?
#
# The average car prices for the top 5 models are:
# Catera: $56,837 (highest).
# DeVille: $46,154.
# Contour: $45,309.
# Integra: $44,604.
# Tacoma: $44,577.

# %% [markdown]
# EDA - 3
#
# 1.  What is the average rating for each product category?
# - Computer Components (Memory, SSDs): 4.45
# - Electronics (Home Audio, Media Streaming): 4.40
# - Office Products (Calculators): 4.38
# - Home & Kitchen (Air Fryers): 4.35
# - Computer Accessories (Keyboards, Mice): 4.30
#
# 2. What are the top rating_count products by category?
# - The top rating_count products by category are Electronics
#
# 3. What is the distribution of discounted prices vs. actual prices ?
#
# didnt understand
#
# 4. How does the average discount percentage vary across categories?
#
# The categories with the highest average discounts are:
# - Electronics (Smart TVs): 45-50%
# - Home & Kitchen Appliances: 35-40%
# - Computer Accessories: 30-35%
# - Office Products: 25-30%
# - Mobile Accessories: 20-25%
#
# 5. What are the most popular product names?
# - Smart TVs (various brands)
# - Laptops
# - Mobile Phones
# - Computer Accessories
# - Home Appliances
# boat and Amazon Basics
#
# 6. What are the most popular product keywords?
#
# Compatibility
#
# 7. What are the most popular product reviews?
#
# Good cable for car, Awesome product, nice product, not as good
#
# 8. What is the correlation between discounted_price and rating?
#
# Correlation between discounted_price and rating:
# The correlation coefficient is approximately -0.15, indicating a weak negative correlation between price and rating. This suggests that higher-priced items don't necessarily receive better ratings.
#
# 9. What are the Top 5 categories based on the highest ratings?
#
# Top 5 Categories Based on Highest Ratings:
# Tablets & Computing: 4.60
#
# Computer Components: 4.50
#
# Power Accessories: 4.50
#
# Home Improvement: 4.50
#
# Office Electronics: 4.45
#
#
#
#
# 10. Identify any potential areas for improvement or optimization based on the data analysis.
#
# Based on review counts and ratings combined, the top products are:
#
# Areas for Improvement/Optimization:
#
# a. Pricing Strategy:
# - Some categories show high discounts but lower ratings
# - Consider optimizing pricing in categories with low rating-to-price ratios
#
# b. Product Quality:
# - Categories with below-average ratings (< 4.0) need quality improvement
# - Focus on improving products in categories with high return rates
#
# c. Review System:
# - Some products have very few ratings despite being listed for a while
# - Implement strategies to encourage more customer reviews
#
# d. Category Management:
# - Some categories have very few products
# - Consider expanding product range in under-represented categories
#
# e. Customer Satisfaction:
# - Address categories with consistently lower ratings
# - Implement quality control measures for poorly-rated products

# %% [markdown]
# EDA - 4
#
# 1. Read the dataframe, check null value if present then do the needful, check duplicate row , if present then do the needful.
#
# The dataset has no null values but contains 27 duplicate rows (removed)
#
# 2. What is the distribution of popularity among the tracks in the dataset? Visualize it using a histogram
#
# The distribution of popularity among the tracks in the dataset shows that most tracks have moderate popularity, with fewer tracks being either highly popular or very unpopular.
#
# Visualize it using a histogram
#
# import matplotlib.pyplot as plt
#
# # Visualize the distribution of popularity
# plt.figure(figsize=(10, 6))
#
# plt.hist(df['Popularity'], bins=30, edgecolor='black')
#
# plt.title('Distribution of Track Popularity')
#
# plt.xlabel('Popularity')
#
# plt.ylabel('Number of Tracks')
#
# plt.grid(True)
#
# plt.show()
#
#
# 3. Is there any relationship between the popularity and the duration of tracks? Explore this using a scatter plot
#
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# # Scatter plot to visualize the relationship between popularity and duration of tracks
# plt.figure(figsize=(10, 6))
#
# sns.scatterplot(x='Duration (ms)', y='Popularity', data=spotify_data)
#
# plt.title('Relationship Between Track Duration and Popularity')
#
# plt.xlabel('Duration (ms)')
#
# plt.ylabel('Popularity')
#
# plt.show()
#
# 4. Which artist has the highest number of tracks in the dataset? Display the count of tracks for each artist using a countplot
#
# Answer is Drake
#
# 5. What are the top 5 least popular tracks in the dataset? Provide the artist name and track name for each
#
# Pressa	Attachments - (feat. Coi Leray)	= Popularity - 29
# Justin Bieber - Intentions = Popularity - 35
# French Montana - Splash Brothers = Popularity - 44
# Lil Baby - On Me - Remix = Popularity - 47
# Wyclef Jean -	911 (feat. Mary J. Blige) = Popularity - 48
#
# 6.  Among the top 5 most popular artists, which artist has the highest popularity on average? Calculate and display the average popularity for each artist
#
# cassÃ¶	92
#
# Trueno	89
#
# David Guetta	87
#
# Travis Scott	87
#
# Â¥$	86
#
#
# Average popularity score for each:
#
# cassÃ¶	92
# Trueno	89
# David Guetta	87
# Travis Scott	87
# Â¥$	86.09090909
# Post Malone	85.22222222
# Anuel AA	85
# Kendrick Lamar	84.5
# 21 Savage	84.18181818
# Dua Lipa	84
# Metro Boomin	83.8
# Eminem	83.63636364
# Drake	83.5
# Bizarrap	83.44444444
# Baby Keem	83
# J. Cole	82.875
# Dave	82
# Don Toliver	82
# SAIKO	82
# Future	81.83333333
# Quevedo	81.66666667
# Nicki Minaj	81.44444444
# Playboi Carti	81.16666667
# Jessie J	81
# SZA	81
# A Boogie Wit da Hoodie	80
# ReneÃ© Rapp	80
# Lil Uzi Vert	79.25
# Dr. Dre	79
# Internet Money	79
# Maroon 5	79
# The Weeknd	79
# Gunna	78.5
# Flo Rida	78
# PinkPantheress	78
# JAY-Z	77.9
# Jack Harlow	77.71428571
# Jung Kook	77.66666667
# Lil Baby	77.5
# Central Cee	77.16666667
# Bruno Mars	77
# Noah Kahan	77
# Quality Control	77
# Cardi B	76.66666667
# Kodak Black	76.57142857
# Lil Nas X	76.09090909
# BigXthaPlug	76
# Ed Sheeran	76
# Gucci Mane	76
# Lil Tecca	76
# Lil Tjay	76
# Oscar Maydon	76
# Rauw Alejandro	76
# Grand Total	75.73636364
# Offset	75.16666667
# Chris Brown	75
# Sarz	75
# Ice Spice	74.85714286
# KAROL G	74.5
# Yeat	74.5
# Lil Wayne	74.25
# Justin Timberlake	74
# Lil Durk	74
# Young Thug	73.75
# Blxst	73
# GloRilla	73
# The Kid LAROI	73
# DaBaby	72.28571429
# 2 Chainz	72
# benny blanco	72
# Pharrell Williams	72
# Taylor Swift	72
# XXXTENTACION	72
# Wiz Khalifa	71.42857143
# Doja Cat	71
# Kane Brown	71
# Megan Thee Stallion	71
# Only The Family	71
# Snoop Dogg	70.875
# DJ Snake	70.66666667
# Lin-Manuel Miranda	70.5
# Tyga	70.2
# Leslie Odom Jr.	70
# Nardo Wick	70
# A$AP Ferg	69
# Timbaland	69
# Quavo	68.6
# D-Block Europe	68.55555556
# ATL Jacob	68
# Skrillex	68
# *NSYNC	67
# Young Nudy	67
# Latto	66.6
# Kanye West	66
# Lyrical Lemonade	66
# Jason Derulo	65.5
# Rick Ross	65.4
# Diddy	65
# DJ Khaled	64.5
# Ellie Goulding	64
# Fat Joe	64
# Juice WRLD	64
# Clavish	63
# Ludacris	63
# Fugees	62.66666667
# Camila Cabello	61
# NEIKED	61
# Coi Leray	60.6
# French Montana	60.57142857
# That Mexican OT	60
# Fivio Foreign	58
# RAYE	55
# Wyclef Jean	54.5
# Arizona Zervas	54
# Justin Bieber	49
# Pressa	29
#
# 7. For the top 5 most popular artists, what are their most popular tracks? List the track name for each artist
#
# Â¥$:
# BACK TO ME
# BURN
# CARNIVAL
# DO IT
# FUK SUMN
# PAID
# PAPERWORK
# STARS
# TALKING
# VULTURES
#
#
# cassÃ¶:
# Prada
#
#
# David Guetta:
# Baby Don't Hurt Me
#
#
# Travis Scott:
# CIRCUS MAXIMUS (feat. The Weeknd & Swae Lee)
# FE!N (feat. Playboi Carti)
# goosebumps
# I KNOW ?
# MELTDOWN (feat. Drake)
# MY EYES
# SICKO MODE
# SKITZO (feat. Young Thug)
# TELEKINESIS (feat. SZA & Future)
#
#
# Trueno:
# Mamichula - con Nicki Nicole
#
# 8. Visualize relationships between multiple numerical variables simultaneously using a pair plot
#
# import seaborn as sns
#
# import matplotlib.pyplot as plt
#
# # Pair plot to visualize relationships between numerical variables
#
# sns.pairplot(spotify_data[['Popularity', 'Duration (ms)']])
#
# plt.show()
#
#
#
# 9. Does the duration of tracks vary significantly across different artists? Explore this visually using a box plot or violin plot
#
# # Box plot to visualize track duration across different artists
#
# plt.figure(figsize=(12, 6))
#
# sns.boxplot(x='Artist', y='Duration (ms)', data=spotify_data)
#
# plt.xticks(rotation=90)
#
# plt.title('Track Duration Across Different Artists')
#
# plt.show()
#
# # Violin plot (alternative visualization)
# plt.figure(figsize=(12, 6))
#
# sns.violinplot(x='Artist', y='Duration (ms)', data=spotify_data)
#
# plt.xticks(rotation=90)
#
# plt.title('Track Duration Across Different Artists')
#
# plt.show()
#
#
#
#
#
#
# 10. How does the distribution of track popularity vary for different artists? Visualize this using a swarm plot or a violin plot.
#
# # Swarm plot to visualize track popularity distribution across different artists
# plt.figure(figsize=(12, 6))
#
# sns.swarmplot(x='Artist', y='Popularity', data=spotify_data)
#
# plt.xticks(rotation=90)
#
# plt.title('Track Popularity Distribution Across Different Artists')
#
# plt.show()
#
#
# # Violin plot (alternative visualization)
# plt.figure(figsize=(12, 6))
#
# sns.violinplot(x='Artist', y='Popularity', data=spotify_data)
#
# plt.xticks(rotation=90)
#
# plt.title('Track Popularity Distribution Across Different Artists')
#
# plt.show()
